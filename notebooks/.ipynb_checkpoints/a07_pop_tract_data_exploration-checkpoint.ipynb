# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_columns',500)
sns.set()

# %%
def top_value_counts(df, n=5, only_categories = True, cols_to_include = None):
    """ Function to generate summary information for string or categorical
    data in dataframes"""
    if cols_to_include:
        df = df[cols_to_include]
    if only_categories:
        df = df.select_dtypes(include=['O','category'])
    cols = df.columns
    df_value_counts = pd.DataFrame()
    i_name = -1
    for col in cols:
        i_name += 1
        counts = df[col].value_counts(dropna=False)[:n]
        top_n_names = list(counts.index)
        top_n = list(counts)
        if len(top_n) < n+1:
            for i in range(n-len(top_n)):
                top_n.append('-')
                top_n_names.append('-')
        top_n_names.insert(0,'n_unique')
        top_n.insert(0,df[col].nunique())
        df_value_counts[col] = top_n_names
        df_value_counts[i_name] = top_n
    return(df_value_counts)

# %%
pop_tract = pd.read_csv('pop_tract.csv')

# %%
pop_tract.head()
# Out:
#         GEOID                                       NAME    variable  \
# 0  1001020100  Census Tract 201, Autauga County, Alabama  B01003_001
# 1  1001020200  Census Tract 202, Autauga County, Alabama  B01003_001
# 2  1001020300  Census Tract 203, Autauga County, Alabama  B01003_001
# 3  1001020400  Census Tract 204, Autauga County, Alabama  B01003_001
# 4  1001020500  Census Tract 205, Autauga County, Alabama  B01003_001
#
#    estimate    moe
# 0      2010  231.0
# 1      2196  281.0
# 2      3136  355.0
# 3      4563  464.0
# 4     10529  655.0

# %%
pop_tract['estimate'].describe()
# Out:
# count    73056.000000
# mean      4360.465424
# std       2176.229512
# min          0.000000
# 25%       2901.000000
# 50%       4085.000000
# 75%       5473.000000
# max      61133.000000
# Name: estimate, dtype: float64

# %%
fig,ax = plt.subplots()
ax.set_xlim(0,20000)
pop_tract['estimate'].hist(bins=50,ax=ax)

# %%
pop_tract.shape
# Out:
# (73056, 5)

# %%
county_pop = pd.read_csv('cc-est2018-alldata.csv',encoding='latin-1')

# %%
county_pop.head()
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    54571
# 1      50      1       1  Alabama  Autauga County     1       1     3579
# 2      50      1       1  Alabama  Autauga County     1       2     3991
# 3      50      1       1  Alabama  Autauga County     1       3     4290
# 4      50      1       1  Alabama  Autauga County     1       4     4290
#
#    TOT_MALE  TOT_FEMALE  WA_MALE  WA_FEMALE  BA_MALE  BA_FEMALE  IA_MALE  \
# 0     26569       28002    21295      22002     4559       5130      119
# 1      1866        1713     1411       1316      362        317        5
# 2      2001        1990     1521       1526      399        374       14
# 3      2171        2119     1658       1620      431        406       15
# 4      2213        2077     1628       1585      502        424       12
#
#    IA_FEMALE  AA_MALE  AA_FEMALE  NA_MALE  NA_FEMALE  TOM_MALE  TOM_FEMALE  \
# ...
