# %% [markdown]
# # Geocode NFIRS datapoints using Census Geocoder API

# %% [markdown]
# It took roughly 30 minutes to geocode 10,000 rows, which would mean it would take on the order of 100 hours to geocode the whole dataset, so I decided not to bother with geocoding the whole thing at this point. The code to do it is here though.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from io import StringIO
import requests

# %matplotlib inline
pd.set_option('display.max_columns',500)
sns.set()

# %%
def top_value_counts(df, n=5, only_categories = True, cols_to_include = None, cols_to_exclude = None):
    """ Function to generate summary information for string or categorical
    data in dataframes"""
    if cols_to_include:
        df = df[cols_to_include]
    if cols_to_exclude:
        df = df[df.columns[~df.columns.isin(cols_to_exclude)]]
    if only_categories:
        df = df.select_dtypes(include=['O','category'])
    cols = df.columns
    df_value_counts = pd.DataFrame()
    i_name = -1
    for col in cols:
        i_name += 1
        counts = df[col].value_counts(dropna=False)[:n]
        top_n_names = list(counts.index)
        top_n = list(counts)
        if len(top_n) < n+1:
            for i in range(n-len(top_n)):
                top_n.append('-')
                top_n_names.append('-')
        top_n_names.insert(0,'n_unique')
        top_n.insert(0,df[col].nunique())
        df_value_counts[col] = top_n_names
        df_value_counts[i_name] = top_n
    return(df_value_counts)

# %%
import os

# %%
os.chdir('../data/02_interim/10000row_chunks')
os.getcwd()
# Out:
# 'C:\\Users\\thwhi\\Dropbox\\Personal\\Programming\\DataKind Red Cross Project\\data\\02_interim\\10000row_chunks'

# %%
def get_chunk_data(filename,output_filename):
    url = 'https://geocoding.geo.census.gov/geocoder/geographies/addressbatch'
    payload = {'benchmark':'Public_AR_Current','vintage':'Current_Current'}
    files = {'addressFile':(filename,open(filename,'rb'), 'text/csv')}
    response = requests.post(url, files=files, data=payload)
    
    cols = ['rcp2_id','original_address','match','match_type','matched_address','latlon','tigerline','tigerside',
            'geo_state_id','geo_county_id','geo_census_tract_id','geo_census_block_id']
    results = pd.read_csv(StringIO(response.text),names=cols,dtype=str)
    
    results['geo_id'] = results['geo_state_id'] + results['geo_county_id'] + results['geo_census_tract_id'] + results['geo_census_block_id']
    results[['lon','lat']] = results['latlon'].str.split(',',expand=True)
    results.to_csv(output_filename,index=False)
    return

# %%
# Iterate through all the 10,000 row address files and return a csv with the associated geo_ids
# This took ~ 30 minutes per file with 10,000 rows, and since there are 196 rows, this will take on the order of 100 hours to complete

FLAG = False

if Flag:
    for filename in os.listdir():
        if filename.endswith('.csv'):
            print('Working on: ', filename)
            output_filename = '../10000row_geoid_output/output_' + filename
            get_chunk_data(filename,output_filename)
# Out:
# Working on:  nfirs_addresses0.csv
# Working on:  nfirs_addresses1.csv
# Working on:  nfirs_addresses10.csv
# Working on:  nfirs_addresses100.csv
# Working on:  nfirs_addresses101.csv
# Working on:  nfirs_addresses102.csv
# Working on:  nfirs_addresses103.csv
# Working on:  nfirs_addresses104.csv
# Working on:  nfirs_addresses105.csv
# Working on:  nfirs_addresses106.csv
# Working on:  nfirs_addresses107.csv
# Working on:  nfirs_addresses108.csv
# Working on:  nfirs_addresses109.csv
# Working on:  nfirs_addresses11.csv
# Working on:  nfirs_addresses110.csv
# Working on:  nfirs_addresses111.csv
# Working on:  nfirs_addresses112.csv
# Working on:  nfirs_addresses113.csv
# Working on:  nfirs_addresses114.csv
# Working on:  nfirs_addresses115.csv
# Working on:  nfirs_addresses116.csv
# Working on:  nfirs_addresses117.csv
# Working on:  nfirs_addresses118.csv
# Working on:  nfirs_addresses119.csv
# Working on:  nfirs_addresses12.csv
# Working on:  nfirs_addresses120.csv
# Working on:  nfirs_addresses121.csv
# Working on:  nfirs_addresses122.csv
# Working on:  nfirs_addresses123.csv
# Working on:  nfirs_addresses124.csv
# Working on:  nfirs_addresses125.csv
# Working on:  nfirs_addresses126.csv
# Working on:  nfirs_addresses127.csv
# Working on:  nfirs_addresses128.csv
# Working on:  nfirs_addresses129.csv
# Working on:  nfirs_addresses13.csv
# Working on:  nfirs_addresses130.csv
# Working on:  nfirs_addresses131.csv
# Working on:  nfirs_addresses132.csv
# Working on:  nfirs_addresses133.csv
# Working on:  nfirs_addresses134.csv
# Working on:  nfirs_addresses135.csv
# Working on:  nfirs_addresses136.csv
# Working on:  nfirs_addresses137.csv
# Working on:  nfirs_addresses138.csv
# Working on:  nfirs_addresses139.csv
# Working on:  nfirs_addresses14.csv
# Working on:  nfirs_addresses140.csv
# Working on:  nfirs_addresses141.csv
# Working on:  nfirs_addresses142.csv
# Working on:  nfirs_addresses143.csv
# Working on:  nfirs_addresses144.csv
# Working on:  nfirs_addresses145.csv
# Working on:  nfirs_addresses146.csv
# Working on:  nfirs_addresses147.csv
# Working on:  nfirs_addresses148.csv
# Working on:  nfirs_addresses149.csv
# Working on:  nfirs_addresses15.csv
# Working on:  nfirs_addresses150.csv
# Working on:  nfirs_addresses151.csv
# Working on:  nfirs_addresses152.csv
# Working on:  nfirs_addresses153.csv
# Working on:  nfirs_addresses154.csv
# Working on:  nfirs_addresses155.csv
# Working on:  nfirs_addresses156.csv
# Working on:  nfirs_addresses157.csv
# Working on:  nfirs_addresses158.csv
# Working on:  nfirs_addresses159.csv
# Working on:  nfirs_addresses16.csv
# Working on:  nfirs_addresses160.csv
# Working on:  nfirs_addresses161.csv
# Working on:  nfirs_addresses162.csv
# Working on:  nfirs_addresses163.csv
# Working on:  nfirs_addresses164.csv
# Working on:  nfirs_addresses165.csv
# Working on:  nfirs_addresses166.csv
# Working on:  nfirs_addresses167.csv
# Working on:  nfirs_addresses168.csv
# Working on:  nfirs_addresses169.csv
# Working on:  nfirs_addresses17.csv
# Working on:  nfirs_addresses170.csv
# Working on:  nfirs_addresses171.csv
# Working on:  nfirs_addresses172.csv
# Working on:  nfirs_addresses173.csv
# Working on:  nfirs_addresses174.csv
# Working on:  nfirs_addresses175.csv
# Working on:  nfirs_addresses176.csv
# Working on:  nfirs_addresses177.csv
# Working on:  nfirs_addresses178.csv
# Working on:  nfirs_addresses179.csv
# Working on:  nfirs_addresses18.csv
# Working on:  nfirs_addresses180.csv
# Working on:  nfirs_addresses181.csv
# Working on:  nfirs_addresses182.csv
# Working on:  nfirs_addresses183.csv
# Working on:  nfirs_addresses184.csv
# Working on:  nfirs_addresses185.csv
# Working on:  nfirs_addresses186.csv
# Working on:  nfirs_addresses187.csv
# Working on:  nfirs_addresses188.csv
# Working on:  nfirs_addresses189.csv
# Working on:  nfirs_addresses19.csv
# Working on:  nfirs_addresses190.csv
# Working on:  nfirs_addresses191.csv
# Working on:  nfirs_addresses192.csv
# Working on:  nfirs_addresses193.csv
# Working on:  nfirs_addresses194.csv
# Working on:  nfirs_addresses195.csv
# Working on:  nfirs_addresses2.csv
# Working on:  nfirs_addresses20.csv
# Working on:  nfirs_addresses21.csv
# Working on:  nfirs_addresses22.csv
# Working on:  nfirs_addresses23.csv
# Working on:  nfirs_addresses24.csv
# Working on:  nfirs_addresses25.csv
# Working on:  nfirs_addresses26.csv
# Working on:  nfirs_addresses27.csv
# Working on:  nfirs_addresses28.csv
# Working on:  nfirs_addresses29.csv
# Working on:  nfirs_addresses3.csv
# Working on:  nfirs_addresses30.csv
# Working on:  nfirs_addresses31.csv
# Working on:  nfirs_addresses32.csv
# Working on:  nfirs_addresses33.csv
# Working on:  nfirs_addresses34.csv
# Working on:  nfirs_addresses35.csv
# Working on:  nfirs_addresses36.csv
# Working on:  nfirs_addresses37.csv
# Working on:  nfirs_addresses38.csv
# Working on:  nfirs_addresses39.csv
# Working on:  nfirs_addresses4.csv
# Working on:  nfirs_addresses40.csv
# Working on:  nfirs_addresses41.csv
# Working on:  nfirs_addresses42.csv
# Working on:  nfirs_addresses43.csv
# Working on:  nfirs_addresses44.csv
# Working on:  nfirs_addresses45.csv
# Working on:  nfirs_addresses46.csv
# Working on:  nfirs_addresses47.csv
# Working on:  nfirs_addresses48.csv
# Working on:  nfirs_addresses49.csv
# Working on:  nfirs_addresses5.csv
# Working on:  nfirs_addresses50.csv
# Working on:  nfirs_addresses51.csv
# Working on:  nfirs_addresses52.csv
# Working on:  nfirs_addresses53.csv
# Working on:  nfirs_addresses54.csv
# Working on:  nfirs_addresses55.csv
# Working on:  nfirs_addresses56.csv
# Working on:  nfirs_addresses57.csv
# Working on:  nfirs_addresses58.csv
# Working on:  nfirs_addresses59.csv
# Working on:  nfirs_addresses6.csv
# Working on:  nfirs_addresses60.csv
# Working on:  nfirs_addresses61.csv
# Working on:  nfirs_addresses62.csv
# Working on:  nfirs_addresses63.csv
# Working on:  nfirs_addresses64.csv
# Working on:  nfirs_addresses65.csv
# Working on:  nfirs_addresses66.csv
# Working on:  nfirs_addresses67.csv
# Working on:  nfirs_addresses68.csv
# Working on:  nfirs_addresses69.csv
# Working on:  nfirs_addresses7.csv
# Working on:  nfirs_addresses70.csv
# Working on:  nfirs_addresses71.csv
# Working on:  nfirs_addresses72.csv
# Working on:  nfirs_addresses73.csv
# Working on:  nfirs_addresses74.csv
# Working on:  nfirs_addresses75.csv
# Working on:  nfirs_addresses76.csv
# Working on:  nfirs_addresses77.csv
# Working on:  nfirs_addresses78.csv
# Working on:  nfirs_addresses79.csv
# Working on:  nfirs_addresses8.csv
# Working on:  nfirs_addresses80.csv
# Working on:  nfirs_addresses81.csv
# Working on:  nfirs_addresses82.csv
# Working on:  nfirs_addresses83.csv
# Working on:  nfirs_addresses84.csv
# Working on:  nfirs_addresses85.csv
# Working on:  nfirs_addresses86.csv
# Working on:  nfirs_addresses87.csv
# Working on:  nfirs_addresses88.csv
# Working on:  nfirs_addresses89.csv
# Working on:  nfirs_addresses9.csv
# Working on:  nfirs_addresses90.csv
# Working on:  nfirs_addresses91.csv
# Working on:  nfirs_addresses92.csv
# Working on:  nfirs_addresses93.csv
# Working on:  nfirs_addresses94.csv
# Working on:  nfirs_addresses95.csv
# Working on:  nfirs_addresses96.csv
# Working on:  nfirs_addresses97.csv
# Working on:  nfirs_addresses98.csv
# Working on:  nfirs_addresses99.csv
# Working on:  nfirs_addresses_result0.csv

# %% [markdown]
# # Old Testing Code

# %%
url = 'https://geocoding.geo.census.gov/geocoder/geographies/addressbatch'
payload = {'benchmark':'Public_AR_Current','vintage':'Current_Current'}
files = {'addressFile':('nfirs_addresses0.csv',open('nfirs_addresses0.csv','rb'), 'text/csv')}
response = requests.post(url, files=files, data=payload)

# %%
cols = ['rcp2_id','original_address','match','match_type','matched_address','latlon','tigerline','tigerside',
        'geo_state_id','geo_county_id','geo_census_tract_id','geo_census_block_id']
results = pd.read_csv(StringIO(response.text),names=cols,dtype=str)

# %%
results.head()
# Out:
#        rcp2_id                      original_address     match match_type  \
# 0  rcp2_id5196  London Springs Rd., Pyatt, AR, 72672  No_Match        NaN
# 1  rcp2_id5197  358 Cambridge Lane, Pyatt, AR, 72672  No_Match        NaN
# 2  rcp2_id5198  322 Loblolly Trail, Pyatt, AR, 72672  No_Match        NaN
# 3  rcp2_id5199     761 mc 6040, Yellville, AR, 72687  No_Match        NaN
# 4   rcp2_id645    1701 2ND AVE, FAIRBANKS, AK, 99701     Match      Exact
#
#                       matched_address               latlon  tigerline  \
# 0                                 NaN                  NaN        NaN
# 1                                 NaN                  NaN        NaN
# 2                                 NaN                  NaN        NaN
# 3                                 NaN                  NaN        NaN
# 4  1701 2ND AVE, FAIRBANKS, AK, 99701  -147.74654,64.84433  190893232
#
#   tigerside geo_state_id geo_county_id geo_census_tract_id geo_census_block_id
# 0       NaN          NaN           NaN                 NaN                 NaN
# 1       NaN          NaN           NaN                 NaN                 NaN
# 2       NaN          NaN           NaN                 NaN                 NaN
# 3       NaN          NaN           NaN                 NaN                 NaN
# 4         L           02           090              000200                2004

# %%
results['geo_id'] = results['geo_state_id'] + results['geo_county_id'] + results['geo_census_tract_id'] + results['geo_census_block_id']

# %%
results.head()
# Out:
#        rcp2_id                      original_address     match match_type  \
# 0  rcp2_id5196  London Springs Rd., Pyatt, AR, 72672  No_Match        NaN
# 1  rcp2_id5197  358 Cambridge Lane, Pyatt, AR, 72672  No_Match        NaN
# 2  rcp2_id5198  322 Loblolly Trail, Pyatt, AR, 72672  No_Match        NaN
# 3  rcp2_id5199     761 mc 6040, Yellville, AR, 72687  No_Match        NaN
# 4   rcp2_id645    1701 2ND AVE, FAIRBANKS, AK, 99701     Match      Exact
#
#                       matched_address               latlon  tigerline  \
# 0                                 NaN                  NaN        NaN
# 1                                 NaN                  NaN        NaN
# 2                                 NaN                  NaN        NaN
# 3                                 NaN                  NaN        NaN
# 4  1701 2ND AVE, FAIRBANKS, AK, 99701  -147.74654,64.84433  190893232
#
#   tigerside geo_state_id geo_county_id geo_census_tract_id  \
# 0       NaN          NaN           NaN                 NaN
# 1       NaN          NaN           NaN                 NaN
# 2       NaN          NaN           NaN                 NaN
# 3       NaN          NaN           NaN                 NaN
# 4         L           02           090              000200
#
#   geo_census_block_id           geo_id
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                2004  020900002002004

# %%
results[['lon','lat']] = results['latlon'].str.split(',',expand=True)

# %%
results.head()
# Out:
#        rcp2_id                      original_address     match match_type  \
# 0  rcp2_id5196  London Springs Rd., Pyatt, AR, 72672  No_Match        NaN
# 1  rcp2_id5197  358 Cambridge Lane, Pyatt, AR, 72672  No_Match        NaN
# 2  rcp2_id5198  322 Loblolly Trail, Pyatt, AR, 72672  No_Match        NaN
# 3  rcp2_id5199     761 mc 6040, Yellville, AR, 72687  No_Match        NaN
# 4   rcp2_id645    1701 2ND AVE, FAIRBANKS, AK, 99701     Match      Exact
#
#                       matched_address               latlon  tigerline  \
# 0                                 NaN                  NaN        NaN
# 1                                 NaN                  NaN        NaN
# 2                                 NaN                  NaN        NaN
# 3                                 NaN                  NaN        NaN
# 4  1701 2ND AVE, FAIRBANKS, AK, 99701  -147.74654,64.84433  190893232
#
#   tigerside geo_state_id geo_county_id geo_census_tract_id  \
# 0       NaN          NaN           NaN                 NaN
# 1       NaN          NaN           NaN                 NaN
# 2       NaN          NaN           NaN                 NaN
# 3       NaN          NaN           NaN                 NaN
# 4         L           02           090              000200
#
#   geo_census_block_id           geo_id       lat         lon
# 0                 NaN              NaN       NaN         NaN
# 1                 NaN              NaN       NaN         NaN
# 2                 NaN              NaN       NaN         NaN
# 3                 NaN              NaN       NaN         NaN
# 4                2004  020900002002004  64.84433  -147.74654

# %%
results.to_csv('nfirs_addresses_result0.csv',index=False)

# %%
blah = get_json('https://geocoding.geo.census.gov/geocoder/locations/onelineaddress?address=4600+Silver+Hill+Rd%2C+Suitland%2C+MD+20746&benchmark=9&format=json')

# %%
blah['result']['addressMatches'][0]['coordinates']
# Out:
# {'x': -76.92691, 'y': 38.846542}

# %%
parameters = {'returntype':'geographies','searchtype':'onelineaddress','benchmark':'Public_AR_Current',
              'address':'7423 chummley ct, falls church, VA 22043','format':'json',
             'vintage':'Current_Current'}

# %%
response = requests.get('https://geocoding.geo.census.gov/geocoder/locations/onelineaddress?',params=parameters)

# %%
response = requests.get('https://geocoding.geo.census.gov/geocoder/geographies/onelineaddress?',params=parameters)
print(response.status_code)
response.json()
# Out:
# 200
# {'result': {'input': {'benchmark': {'id': '4',
#     'benchmarkName': 'Public_AR_Current',
#     'benchmarkDescription': 'Public Address Ranges - Current Benchmark',
#     'isDefault': False},
#    'vintage': {'id': '4',
#     'vintageName': 'Current_Current',
#     'vintageDescription': 'Current Vintage - Current Benchmark',
#     'isDefault': True},
#    'address': {'address': '7423 chummley ct, falls church, VA 22043'}},
#   'addressMatches': [{'matchedAddress': '7423 CHUMMLEY CT, FALLS CHURCH, VA, 22043',
#     'coordinates': {'x': -77.200806, 'y': 38.89857},
#     'tigerLine': {'tigerLineId': '75978166', 'side': 'L'},
#     'addressComponents': {'fromAddress': '7401',
#      'toAddress': '7423',
#      'preQualifier': '',
#      'preDirection': '',
#      'preType': '',
#      'streetName': 'CHUMMLEY',
#      'suffixType': 'CT',
#      'suffixDirection': '',
#      'suffixQualifier': '',
#      'city': 'FALLS CHURCH',
#      'state': 'VA',
#      'zip': '22043'},
#     'geographies': {'2010 Census Blocks': [{'SUFFIX': '',
#        'GEOID': '510594713031000',
#        'CENTLAT': '+38.8984255',
#        'BLOCK': '1000',
#        'AREAWATER': 0,
#        'STATE': '51',
#        'BASENAME': '1000',
#        'OID': 210403969163629,
#        'LSADC': 'BK',
#        'FUNCSTAT': 'S',
#        'INTPTLAT': '+38.8984255',
#        'NAME': 'Block 1000',
#        'OBJECTID': 11022711,
#        'TRACT': '471303',
#        'CENTLON': '-077.2008252',
#        'BLKGRP': '1',
#        'AREALAND': 79820,
#        'INTPTLON': '-077.2008252',
#        'MTFCC': 'G5040',
#        'LWBLKTYP': 'L',
#        'COUNTY': '059'}],
#      'States': [{'STATENS': '01779803',
#        'GEOID': '51',
#        'CENTLAT': '+37.5182631',
#        'AREAWATER': 8527942672,
#        'STATE': '51',
#        'BASENAME': 'Virginia',
#        'STUSAB': 'VA',
#        'OID': 2749099610787,
#        'LSADC': '00',
#        'FUNCSTAT': 'A',
#        'INTPTLAT': '+37.5222512',
#        'DIVISION': '5',
#        'NAME': 'Virginia',
#        'REGION': '3',
#        'OBJECTID': 53,
#        'CENTLON': '-078.6759174',
#        'AREALAND': 102258306285,
#        'INTPTLON': '-078.6681938',
#        'MTFCC': 'G4000'}],
#      'Counties': [{'GEOID': '51059',
#        'CENTLAT': '+38.8344842',
#        'AREAWATER': 40107717,
#        'STATE': '51',
#        'BASENAME': 'Fairfax',
#        'OID': 27590241097994,
#        'LSADC': '06',
#        'FUNCSTAT': 'A',
#        'INTPTLAT': '+38.8295203',
#        'NAME': 'Fairfax County',
#        'OBJECTID': 2857,
#        'CENTLON': '-077.2761104',
#        'COUNTYCC': 'H1',
#        'COUNTYNS': '01480119',
#        'AREALAND': 1012703532,
#        'INTPTLON': '-077.2732524',
#        'MTFCC': 'G4020',
#        'COUNTY': '059'}],
#      'Census Tracts': [{'GEOID': '51059471303',
#        'CENTLAT': '+38.8962791',
#        'AREAWATER': 0,
#        'STATE': '51',
#        'BASENAME': '4713.03',
#        'OID': 207903714715758,
#        'LSADC': 'CT',
#        'FUNCSTAT': 'S',
#        'INTPTLAT': '+38.8962791',
#        'NAME': 'Census Tract 4713.03',
#        'OBJECTID': 18963,
#        'TRACT': '471303',
#        'CENTLON': '-077.2091642',
#        'AREALAND': 1372870,
#        'INTPTLON': '-077.2091642',
#        'MTFCC': 'G5020',
#        'COUNTY': '059'}]}}]}}

# %%
data = response.json()['result']['addressMatches'][0]
data.keys()
# Out:
# dict_keys(['matchedAddress', 'coordinates', 'tigerLine', 'addressComponents', 'geographies'])

# %%
geo = data['geographies']
geo
# Out:
# {'Unified School Districts': [{'LOGRADE': 'PK',
#    'GEOID': '5101260',
#    'CENTLAT': '+38.8344842',
#    'AREAWATER': 40107717,
#    'STATE': '51',
#    'BASENAME': 'Fairfax County Public Schools',
#    'OID': 28490241127450,
#    'SDTYP': '',
#    'LSADC': '00',
#    'FUNCSTAT': 'E',
#    'INTPTLAT': '+38.8295203',
#    'SDUNI': '01260',
#    'NAME': 'Fairfax County Public Schools',
#    'OBJECTID': 2695,
#    'CENTLON': '-077.2761104',
#    'HIGRADE': '12',
#    'AREALAND': 1012703532,
#    'INTPTLON': '-077.2732524',
#    'MTFCC': 'G5420'}]}

# %%
len(data)
# Out:
# 1

# %%
response.json()
# Out:
# {'result': {'input': {'benchmark': {'id': '4',
#     'benchmarkName': 'Public_AR_Current',
#     'benchmarkDescription': 'Public Address Ranges - Current Benchmark',
#     'isDefault': False},
#    'address': {'address': '7423 chummley ct, falls church, VA 22043'}},
#   'addressMatches': [{'matchedAddress': '7423 CHUMMLEY CT, FALLS CHURCH, VA, 22043',
#     'coordinates': {'x': -77.200806, 'y': 38.89857},
#     'tigerLine': {'tigerLineId': '75978166', 'side': 'L'},
#     'addressComponents': {'fromAddress': '7401',
#      'toAddress': '7423',
#      'preQualifier': '',
#      'preDirection': '',
#      'preType': '',
#      'streetName': 'CHUMMLEY',
#      'suffixType': 'CT',
#      'suffixDirection': '',
#      'suffixQualifier': '',
#      'city': 'FALLS CHURCH',
#      'state': 'VA',
#      'zip': '22043'}}]}}

# %%
blah3 = requests.get('https://geocoding.geo.census.gov/geocoder/geographies/address?street=4600+Silver+Hill+Rd&city=Suitland&state=MD&benchmark=Public_AR_Census2010&vintage=Census2010_Census2010&layers=14&format=json')

# %%
blah3.json()
# Out:
# {'result': {'input': {'benchmark': {'id': '9',
#     'benchmarkName': 'Public_AR_Census2010',
#     'benchmarkDescription': 'Public Address Ranges - Census 2010 Benchmark',
#     'isDefault': False},
#    'vintage': {'id': '910',
#     'vintageName': 'Census2010_Census2010',
#     'vintageDescription': 'Census2010 Vintage - Census2010 Benchmark',
#     'isDefault': True},
#    'address': {'street': '4600 Silver Hill Rd',
#     'city': 'Suitland',
#     'state': 'MD'}},
#   'addressMatches': [{'matchedAddress': '4600 Silver Hill Rd, SUITLAND, MD, 20746',
#     'coordinates': {'x': -76.92691, 'y': 38.846542},
#     'tigerLine': {'tigerLineId': '613199520', 'side': 'L'},
#     'addressComponents': {'fromAddress': '4600',
#      'toAddress': '4712',
#      'preQualifier': '',
#      'preDirection': '',
#      'preType': '',
#      'streetName': 'Silver Hill',
#      'suffixType': 'Rd',
#      'suffixDirection': '',
#      'suffixQualifier': '',
#      'city': 'SUITLAND',
#      'state': 'MD',
#      'zip': '20746'},
#     'geographies': {'Census Blocks': [{'SUFFIX': '',
#        'POP100': 0,
#        'GEOID': '240338024051084',
#        'CENTLAT': '+38.8477828',
#        'BLOCK': '1084',
#        'AREAWATER': 0,
#        'STATE': '24',
#        'BASENAME': '1084',
#        'OID': 210403970691471,
#        'LSADC': 'BK',
#        'FUNCSTAT': 'S',
#        'INTPTLAT': '+38.8477828',
#        'NAME': 'Block 1084',
#        'OBJECTID': 4385889,
#        'TRACT': '802405',
#        'CENTLON': '-076.9266698',
#        'BLKGRP': '1',
#        'AREALAND': 33460,
#        'HU100': 0,
#        'INTPTLON': '-076.9266698',
#        'MTFCC': 'G5040',
#        'LWBLKTYP': 'L',
#        'UR': '',
#        'COUNTY': '033'}]}}]}}
