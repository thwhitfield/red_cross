# %% [markdown]
# # Machine Learning Classifier
# Assign scores to predict the potential improvement in safety by installing smoke detectors in that area

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %matplotlib inline
pd.set_option('display.max_columns',500)
sns.set()

# %%
nfirs = pd.read_csv('../data/02_interim/03_nfirs_geoids.csv',dtype={'geoid':str})
# Out:
# C:\Users\thwhi\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (2,3,6,16,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# 1. Read in data
# 2. Look at the descriptive statistics of the label (in this case smoke alarm presence)
# 2. Data cleaning
# 3. feature engineering
# 4. initial classifier (logistic regression)

# %% [markdown]
# How to determine if a given geographic area is less likely to have fire alarms? You can look at the number of fires, and the fraction of those fires which have smoke alarms in them. Seems easy enough.
#
# The big problem is that it seems that the fire alarm data isn't always filled in. Either it's unknown for a lot of fires, or perhaps some fire departments just don't fill it in.

# %%
def null_counts(df):
    null_df = pd.DataFrame(df.isnull().sum(),columns=['null_count'])
    null_df['null_fraction'] = null_df['null_count'] / df.shape[0]
    null_df = null_df.sort_values('null_count',ascending=False)
    return null_df

# %%
null_counts(nfirs)
# Out:
#                  null_count  null_fraction
# aes_fail            1955785       0.998305
# no_spr_op           1935953       0.988182
# aes_oper            1932703       0.986523
# aes_type            1929975       0.985130
# det_fail            1904639       0.972198
# det_effect          1682810       0.858968
# det_operat          1500748       0.766037
# det_type            1497389       0.764323
# det_power           1492512       0.761833
# oth_inj             1188360       0.606583
# oth_death           1188360       0.606583
# aes_pres             925886       0.472606
# detector             925886       0.472606
# match                392184       0.200185
# match_type           392184       0.200185
# tiger_line_id        392184       0.200185
# tiger_line_side      392184       0.200185
# geoid                320195       0.163439
# lon                  320195       0.163439
# lat                  320195       0.163439
# cont_loss             45895       0.023427
# prop_loss             45379       0.023163
# street                 3917       0.001999
# state                   120       0.000061
# city                      8       0.000004
# zip5                      7       0.000004
# tot_loss                  0       0.000000
# inc_type                  0       0.000000
# exp_no                    0       0.000000
# inc_date                  0       0.000000
# inc_no                    0       0.000000
# fdid                      0       0.000000
# rcp2_id                   0       0.000000

# %%
nfirs.head()
# Out:
#     rcp2_id state   fdid inc_no    city            street   zip5    inc_date  \
# 0  rcp2_id1    AK  11100    211  JUNEAU    1700 ANGUS WAY  99801  2009-01-03
# 1  rcp2_id2    AK  11100    470  JUNEAU  3221 PIONEER AVE  99801  2009-01-06
# 2  rcp2_id3    AK  11100    556  JUNEAU   10231 HERON WAY  99801  2009-01-06
# 3  rcp2_id4    AK  11100   1315  JUNEAU  6590 GLACIER HWY  99801  2009-01-13
# 4  rcp2_id5    AK  11100   2151  JUNEAU  6590 GLACIER HWY  99801  2009-01-21
#
#    oth_inj  oth_death  exp_no  inc_type  prop_loss  cont_loss  tot_loss  \
# 0      0.0        0.0     0.0       111    20000.0     5000.0   25000.0
# 1      0.0        0.0     0.0       114        0.0        0.0       0.0
# 2      0.0        0.0     0.0       111    20000.0     5000.0   25000.0
# 3      0.0        0.0     0.0       113      200.0       20.0     220.0
# 4      0.0        0.0     0.0       111    35000.0     5000.0   40000.0
#
#   detector det_type det_power det_operat det_effect det_fail aes_pres  \
# 0        1        1         1          2          1      NaN        N
# 1      NaN      NaN       NaN        NaN        NaN      NaN      NaN
# 2        N      NaN       NaN        NaN        NaN      NaN        N
# 3      NaN      NaN       NaN        NaN        NaN      NaN      NaN
# 4        N      NaN       NaN        NaN        NaN      NaN        N
#
#   aes_type aes_oper  no_spr_op aes_fail        geoid  match match_type  \
# 0      NaN      NaN        NaN      NaN  02110000500  Match      Exact
# 1      NaN      NaN        NaN      NaN  02110000600  Match      Exact
# 2      NaN      NaN        NaN      NaN  02110000100  Match      Exact
# 3      NaN      NaN        NaN      NaN  02110000400  Match      Exact
# 4      NaN      NaN        NaN      NaN  02110000400  Match      Exact
#
#    tiger_line_id tiger_line_side        lon        lat
# 0    190964136.0               R -134.42440  58.306507
# 1    190966361.0               R -134.43314  58.292686
# 2    190962538.0               R -134.60330  58.402610
# 3    190963741.0               R -134.51932  58.358955
# 4    190963741.0               R -134.51932  58.358955

# %%
nfirs['detector'].value_counts(dropna=False)
# Out:
# NaN    925886
# 1      466610
# U      301345
# N      265265
# Name: detector, dtype: int64

# %% [markdown]
# About 50% of the entries are NaN, and then another 15% are listed as U. So it's unknown whether there's a fire alarm in about 65% of the homes where there are fires.

# %%
nfirs['detector'].value_counts(dropna=False).plot.bar()

# %%
# So, I want to aggregate the smoke detector statistics by geoid

geoids = pd.crosstab(nfirs['geoid'],nfirs['detector'].fillna('nan'))

# %%
geoids['ratio_1_N'] = geoids['1'] / (geoids['1'] + geoids['N'])

# %%
geoids['tot_fires'] = geoids[['1','N','U','nan']].sum(axis=1)
geoids['ratio_tot'] = geoids['1'] / geoids['tot_fires']

# %%
cols_to_add = ['geoid','city','state','fdid']
geoids = (geoids.reset_index()
          .merge(nfirs[cols_to_add].drop_duplicates(subset='geoid'),
                 how='left',left_on='geoid',right_on='geoid')
          .set_index('geoid')
          .sort_index())

# %%
geoids.sort_values(['ratio_tot','1'],ascending=False).head()
# Out:
#               1  N  U  nan  ratio_1_N  tot_fires  ratio_tot          city  \
# geoid
# 42101005600  27  0  0    0        1.0         27        1.0  PHILADELPHIA
# 42101012201  24  0  0    0        1.0         24        1.0  PHILADELPHIA
# 42101000100  19  0  0    0        1.0         19        1.0  PHILADELPHIA
# 42101000401  18  0  0    0        1.0         18        1.0  PHILADELPHIA
# 39035109701  17  0  0    0        1.0         17        1.0     CLEVELAND
#
#             state   fdid
# geoid
# 42101005600    PA  51001
# 42101012201    PA  51001
# 42101000100    PA  51001
# 42101000401    PA  51001
# 39035109701    OH  18027

# %%
geoids.sort_values(['ratio_tot','N'],ascending=False).head()
# Out:
#              1  N  U  nan  ratio_1_N  tot_fires  ratio_tot         city state  \
# geoid
# 01007010004  1  0  0    0        1.0          1        1.0  Centreville    AL
# 01071951100  1  0  0    0        1.0          1        1.0       dutton    AL
# 01079979200  1  0  0    0        1.0          1        1.0   town creek    AL
# 01101000100  1  0  0    0        1.0          1        1.0   MONTGOMERY    AL
# 01101001500  2  0  0    0        1.0          2        1.0   MONTGOMERY    AL
#
#               fdid
# geoid
# 01007010004  00702
# 01071951100   3906
# 01079979200   4210
# 01101000100   0313
# 01101001500   0313

# %% [markdown]
# So, it appears that some areas have almost no locations where fires occur with a smoke detector, while in other locations almost every location with a fire has a smoke detector.
#
# For now, I won't worry too much about the possible data provenance and quality issues, and just create a classifier using the available data to see what it looks like.
#
# One way to do that though would be to groupby fire department id to see if specific fire departments tend to mark a surprising number of fires as being in areas without a smoke detector. Though it'll always be difficult to determine if it's just an area that doesn't have many smoke detectors or if it's that a given fire department is less diligent about checking whether there's a smoke detector.

# %% [markdown]
# 1. Add leading zeros to the fdid column to ensure that all of them have a correct, 5-digit fdid
# 2. Concatenate the 2 letter state code to the start of each fdid so that they are now unique identifiers

# %%
nfirs['fdid'] = nfirs['state'] + nfirs['fdid'].astype(str).str.zfill(5)

fdids = pd.crosstab(nfirs['fdid'],nfirs['detector'].fillna('nan'))

fdids['tot_fires'] = fdids[['1','N','U','nan']].sum(axis=1)

fdids['ratio_1_N'] = fdids['1'] / (fdids['1'] + fdids['N'])
fdids['ratio_tot'] = fdids['1'] / fdids['tot_fires']
cols_to_add = ['fdid','city','state']
fdids = (fdids.reset_index()
          .merge(nfirs[cols_to_add].drop_duplicates(subset='fdid'),
                 how='left',left_on='fdid',right_on='fdid'))

fdids = fdids.set_index('fdid')

# %%
fdids[fdids['tot_fires']>100].sort_values(['ratio_tot','tot_fires'],ascending=[True,False]).head()
# Out:
#          1  N    U  nan  tot_fires  ratio_1_N  ratio_tot           city state
# fdid
# MS42001  0  0  225  192        417        NaN        0.0      Greenwood    MS
# MO11102  0  0  309   64        373        NaN        0.0  Mineral Point    MO
# NY30055  0  1    5  193        199        0.0        0.0      ROOSEVELT    NY
# VA78000  0  8   95   72        175        0.0        0.0   South Boston    VA
# NY44020  0  0    0  155        155        NaN        0.0        AIRMONT    NY

# %%
fdids[fdids['tot_fires']>100].sort_values(['ratio_tot','tot_fires'],ascending=[False,False]).head()
# Out:
#             1    N    U  nan  tot_fires  ratio_1_N  ratio_tot       city state
# fdid
# VA04100  2056  151  287  201       2695   0.931581   0.762894    CHESTER    VA
# MD15555  2004  136  343  152       2635   0.936449   0.760531  ROCKVILLE    MD
# MEJ0030   279   22   22   51        374   0.926910   0.745989     Bangor    ME
# OR00291  1803  431   74  109       2417   0.807073   0.745966   PORTLAND    OR
# ILLA172   101   13   23    0        137   0.885965   0.737226     Gurnee    IL

# %%
geoids.head()

# %% [markdown]
# Ok, let's take a look at some descriptive statistics about smoke alarms by geoid

# %%
# Histogram of the ratio between confirmed smoke alarms and total fires
geoids['ratio_tot'].hist(bins=20)

# %%
# Ratio between confirmed smoke alarms and just confirmed homes with or without smoke alarms. As you can see, it's markedly different than the previous histogram
geoids['ratio_1_N'].hist(bins=20)

# %% [markdown]
# Now let's look at it by specific fire department

# %%
fdids['ratio_tot'].hist(bins=20)

# %%
fdids['ratio_1_N'].hist(bins=20)

# %%
fdids.head()
# Out:
#           1   N   U  nan  tot_fires  ratio_1_N  ratio_tot     city state
# fdid
# AK11100  73  30  27  129        259   0.708738   0.281853   JUNEAU    AK
# AK12100   7   0   2   17         26   1.000000   0.269231   HAINES    AK
# AK12111   0   0   1    0          1        NaN   0.000000   Haines    AK
# AK12150   0   1   1    3          5   0.000000   0.000000   HAINES    AK
# AK12151   0   0   0    1          1        NaN   0.000000  Klukwan    AK

# %% [markdown]
# From looking at the above charts, it's quite clear that the data on smoke alarms is somewhat questionable. But it's all we've got I suppose, so we'll go with it.

# %%
(fdids['U'].sum() + fdids['nan'].sum()) / fdids['tot_fires'].sum()
# Out:
# 0.6264332670065024

# %% [markdown]
# As you can see, 63% of the detector field was either not entered at all, or a value of undetermined was entered.

# %%
geoids['ratio_tot'].describe()
# Out:
# count    68129.000000
# mean         0.272959
# std          0.209422
# min          0.000000
# 25%          0.117647
# 50%          0.250000
# 75%          0.391304
# max          1.000000
# Name: ratio_tot, dtype: float64

# %%
geoids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68129 entries, 01001020100 to 56045951300
# Data columns (total 10 columns):
# 1            68129 non-null int64
# N            68129 non-null int64
# U            68129 non-null int64
# nan          68129 non-null int64
# ratio_1_N    63511 non-null float64
# tot_fires    68129 non-null int64
# ratio_tot    68129 non-null float64
# city         68129 non-null object
# state        68126 non-null object
# fdid         68129 non-null object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 5.7+ MB

# %%
geoids.head()
# Out:
#               1  N  U  nan  ratio_1_N  tot_fires  ratio_tot        city state  \
# geoid
# 01001020100   6  2  1    4   0.750000         13   0.461538  Prattville    AL
# 01001020200   3  3  2    9   0.500000         17   0.176471  Prattville    AL
# 01001020300   5  6  2   12   0.454545         25   0.200000  Prattville    AL
# 01001020400   3  6  6    7   0.333333         22   0.136364  Prattville    AL
# 01001020500  16  0  6   39   1.000000         61   0.262295  Prattville    AL
#
#             fdid
# geoid
# 01001020100  401
# 01001020200  401
# 01001020300  401
# 01001020400  401
# 01001020500  401

# %% [markdown]
# # County Level Data aggregation

# %%
nfirs['county_geoid'] = '0500000US' + nfirs['geoid'].str[:5]

# %%
counties = pd.crosstab(nfirs['county_geoid'],nfirs['detector'].fillna('nan'))
counties['ratio_1_N'] = counties['1'] / (counties['1'] + counties['N']) 

counties['tot_fires'] = counties[['1','N','U','nan']].sum(axis=1)
counties['ratio_tot'] = counties['1'] / counties['tot_fires']

cols_to_add = ['county_geoid','city','state','fdid']
counties = (counties.reset_index()
          .merge(nfirs[cols_to_add].drop_duplicates(subset='county_geoid'),
                 how='left',left_on='county_geoid',right_on='county_geoid')
          .set_index('county_geoid')
          .sort_index())

counties.sort_values(['ratio_tot','1'],ascending=False).head()
# Out:
#                 1  N  U  nan  ratio_1_N  tot_fires  ratio_tot        city  \
# county_geoid
# 0500000US27049  5  0  0    0        1.0          5        1.0    Zumbrota
# 0500000US27043  4  0  0    0        1.0          4        1.0   Winnebago
# 0500000US20063  3  0  0    0        1.0          3        1.0  Grainfield
# 0500000US27133  2  0  0    0        1.0          2        1.0     Luverne
# 0500000US46003  2  0  0    0        1.0          2        1.0  Plankinton
#
#                state     fdid
# county_geoid
# 0500000US27049    MN  MN25108
# 0500000US27043    MN  MN22111
# 0500000US20063    KS  KSGO302
# 0500000US27133    MN  MN67105
# 0500000US46003    SD  SD10001

# %%
counties[counties['tot_fires']>100].sort_values(['ratio_tot','tot_fires'],ascending=[False,False]).head()
# Out:
#                    1     N     U  nan  ratio_1_N  tot_fires  ratio_tot  \
# county_geoid
# 0500000US24031  1851   127   301   98   0.935794       2377   0.778713
# 0500000US51041  1947   144   276  175   0.931133       2542   0.765932
# 0500000US41051  2064   467   154  128   0.815488       2813   0.733736
# 0500000US42101  8145  2197  1345    2   0.787565      11689   0.696809
# 0500000US41005  1150   186   223  207   0.860778       1766   0.651189
#
#                         city state     fdid
# county_geoid
# 0500000US24031   POOLESVILLE    MD  MD10014
# 0500000US51041       CHESTER    VA  VA04100
# 0500000US41051       Gresham    OR  OR00144
# 0500000US42101  PHILADELPHIA    PA  PA51001
# 0500000US41005        BORING    OR  OR00033

# %%
counties['ratio_score'] = (100 - counties['ratio_tot'] * 100).round(0)

# %%
counties.head()
# Out:
#                   1   N    U  nan  ratio_1_N  tot_fires  ratio_tot  \
# county_geoid
# 0500000US01001   51  22   32   97   0.698630        202   0.252475
# 0500000US01003  229  90  194  229   0.717868        742   0.308625
# 0500000US01005   10   7   29    6   0.588235         52   0.192308
# 0500000US01007    5   0    6    2   1.000000         13   0.384615
# 0500000US01009   48  17   56   59   0.738462        180   0.266667
#
#                        city state     fdid  ratio_score
# county_geoid
# 0500000US01001   Prattville    AL  AL00401         75.0
# 0500000US01003  Bay Minette    AL  AL00501         69.0
# 0500000US01005      Clayton    AL  AL00602         81.0
# 0500000US01007     RANDOLPH    AL  AL00708         62.0
# 0500000US01009      Oneonta    AL  AL00801         73.0

# %%
counties['ratio_score'].hist(bins=20)

# %%
import json

# %%
with open('../data/01_raw/us_counties_20m_topo.json','r') as f:
    county_geo = json.load(f)

# %%
counties.get('0500000US01001','hello')
# Out:
# 'hello'

# %%
import branca

# %%
county_geo['objects']['us_counties_20m']['geometries'][0]['id']
# Out:
# '0500000US01001'

# %%
counties.head()
# Out:
#                   1   N    U  nan  ratio_1_N  tot_fires  ratio_tot  \
# county_geoid
# 0500000US01001   51  22   32   97   0.698630        202   0.252475
# 0500000US01003  229  90  194  229   0.717868        742   0.308625
# 0500000US01005   10   7   29    6   0.588235         52   0.192308
# 0500000US01007    5   0    6    2   1.000000         13   0.384615
# 0500000US01009   48  17   56   59   0.738462        180   0.266667
#
#                        city state     fdid  ratio_score
# county_geoid
# 0500000US01001   Prattville    AL  AL00401         25.0
# 0500000US01003  Bay Minette    AL  AL00501         31.0
# 0500000US01005      Clayton    AL  AL00602         19.0
# 0500000US01007     RANDOLPH    AL  AL00708         38.0
# 0500000US01009      Oneonta    AL  AL00801         27.0

# %%
'0500000US01001' == '0500000US01001'
# Out:
# True

# %%
import folium
import branca

colorscale = branca.colormap.linear.YlOrRd_09.scale(0, 100)
colorscale.caption = 'Percent of homes without fire alarms'

county_alarm_ratio = 100 - counties['ratio_score']

def style_function(feature):
    alarm_ratio = county_alarm_ratio.get(feature['id'],None)
    return {
        'fillOpacity': 0.5,
        'weight': 0,
        'fillColor': '#black' if alarm_ratio is None else colorscale(alarm_ratio)        
    }

m = folium.Map(
    location=[48, -102],
    tiles='cartodbpositron',
    zoom_start=3
)

with open('../data/01_raw/us_counties_20m_topo.json','r') as f:
    county_geo = json.load(f)

folium.TopoJson(
    county_geo,
    'objects.us_counties_20m',
    style_function=style_function
).add_to(m)

# folium.TopoJson(
#     json.loads(requests.get(county_geo).text),
#     'objects.us_counties_20m',
#     style_function=style_function
# ).add_to(m)

colorscale.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, I was able to make a folium map using the topojson file of all the counties in the USA. I wasn't able to plug and play use a choropleth map because the geo_data file wasn't a geojson, but I'm going to see if I can get that working this time around.

# %%
counties.head()
# Out:
#                   1   N    U  nan  ratio_1_N  tot_fires  ratio_tot  \
# county_geoid
# 0500000US01001   51  22   32   97   0.698630        202   0.252475
# 0500000US01003  229  90  194  229   0.717868        742   0.308625
# 0500000US01005   10   7   29    6   0.588235         52   0.192308
# 0500000US01007    5   0    6    2   1.000000         13   0.384615
# 0500000US01009   48  17   56   59   0.738462        180   0.266667
#
#                        city state     fdid  ratio_score
# county_geoid
# 0500000US01001   Prattville    AL  AL00401         25.0
# 0500000US01003  Bay Minette    AL  AL00501         31.0
# 0500000US01005      Clayton    AL  AL00602         19.0
# 0500000US01007     RANDOLPH    AL  AL00708         38.0
# 0500000US01009      Oneonta    AL  AL00801         27.0

# %%
all_county_ids = [geo['id'] for geo in county_geo['objects']['us_counties_20m']['geometries']]
df_all_county_ids = pd.DataFrame(all_county_ids,columns=['county_geoid'])
df_all_county_ids = df_all_county_ids.merge(counties,how='left',left_on='county_geoid',right_index=True)
# df_all_county_ids = df_all_county_ids.set_index('county_geoid')

# %%
df_all_county_ids
# Out:
#         county_geoid       1      N      U    nan  ratio_1_N  tot_fires  \
# 0     0500000US01001    51.0   22.0   32.0   97.0   0.698630      202.0
# 1     0500000US01009    48.0   17.0   56.0   59.0   0.738462      180.0
# 2     0500000US01017    26.0   27.0   25.0   49.0   0.490566      127.0
# 3     0500000US01021    53.0   20.0  100.0   77.0   0.726027      250.0
# 4     0500000US01033    12.0   10.0   25.0   47.0   0.545455       94.0
# 5     0500000US01045    23.0   24.0   36.0   50.0   0.489362      133.0
# 6     0500000US01051    73.0   39.0  112.0   69.0   0.651786      293.0
# 7     0500000US01065    10.0   10.0   11.0    3.0   0.500000       34.0
# 8     0500000US01079    11.0    4.0   19.0    3.0   0.733333       37.0
# 9     0500000US01083    37.0   13.0   26.0   51.0   0.740000      127.0
# 10    0500000US01099    18.0   18.0   19.0   12.0   0.500000       67.0
# 11    0500000US01107     3.0    4.0   37.0    5.0   0.428571       49.0
# 12    0500000US01121   102.0  112.0  122.0  125.0   0.476636      461.0
# 13    0500000US02050    13.0   26.0   30.0   14.0   0.333333       83.0
# 14    0500000US02105     2.0    1.0    0.0   17.0   0.666667       20.0
# 15    0500000US02122   165.0   77.0   91.0  213.0   0.681818      546.0
# 16    0500000US02150    33.0   14.0   12.0   54.0   0.702128      113.0
# 17    0500000US02164     0.0    4.0    1.0    0.0   0.000000        5.0
# 18    0500000US02180     9.0   10.0    5.0   13.0   0.473684       37.0
# 19    0500000US02188    13.0   12.0    6.0   13.0   0.520000       44.0
# 20    0500000US02198     5.0    6.0   14.0   12.0   0.454545       37.0
# 21    0500000US05141    21.0   24.0   36.0   19.0   0.466667      100.0
# 22    0500000US05145   157.0  161.0  279.0  132.0   0.493711      729.0
# 23    0500000US06005    36.0   12.0   34.0   75.0   0.750000      157.0
# 24    0500000US06021     1.0    3.0    9.0   17.0   0.250000       30.0
# 25    0500000US06033    66.0   67.0  398.0   83.0   0.496241      614.0
# 26    0500000US06043    14.0   22.0    8.0    9.0   0.388889       53.0
# 27    0500000US06055   207.0   48.0   64.0  156.0   0.811765      475.0
# 28    0500000US06089   264.0  114.0  297.0  130.0   0.698413      805.0
# 29    0500000US06099   465.0  318.0  348.0  758.0   0.593870     1889.0
# ...              ...     ...    ...    ...    ...        ...        ...
# 3191  0500000US22003    34.0   30.0   52.0   21.0   0.531250      137.0
# 3192  0500000US22009    26.0   47.0   27.0   13.0   0.356164      113.0
# 3193  0500000US22101    59.0   54.0   71.0   71.0   0.522124      255.0
# 3194  0500000US22107    11.0   28.0   34.0   11.0   0.282051       84.0
# 3195  0500000US22109   135.0  138.0  142.0  179.0   0.494505      594.0
# 3196  0500000US21021    43.0   19.0   31.0   85.0   0.693548      178.0
# 3197  0500000US21023    18.0    5.0   24.0   19.0   0.782609       66.0
# 3198  0500000US22045   131.0  128.0   94.0   42.0   0.505792      395.0
# 3199  0500000US21047    99.0   79.0   78.0  159.0   0.556180      415.0
# 3200  0500000US21055     7.0    5.0   21.0    5.0   0.583333       38.0
# 3201  0500000US21059   120.0   75.0  133.0  718.0   0.615385     1046.0
# 3202  0500000US21073    74.0   22.0   64.0  128.0   0.770833      288.0
# 3203  0500000US21075    24.0   10.0   16.0    7.0   0.705882       57.0
# 3204  0500000US21089    16.0    3.0   45.0   21.0   0.842105       85.0
# 3205  0500000US21095    24.0   17.0   45.0   17.0   0.585366      103.0
# 3206  0500000US55137    30.0   14.0   18.0   43.0   0.681818      105.0
# 3207  0500000US56001    12.0   19.0   11.0   30.0   0.387097       72.0
# 3208  0500000US56007     3.0    4.0   13.0   27.0   0.428571       47.0
# 3209  0500000US56011     2.0    4.0    0.0    0.0   0.333333        6.0
# 3210  0500000US56013    25.0   26.0   51.0   36.0   0.490196      138.0
# 3211  0500000US56021    36.0   31.0   62.0  151.0   0.537313      280.0
# 3212  0500000US54031    29.0   11.0   18.0   76.0   0.725000      134.0
# 3213  0500000US54035    36.0   33.0   29.0   29.0   0.521739      127.0
# 3214  0500000US54041    46.0   21.0   34.0   12.0   0.686567      113.0
# 3215  0500000US50027    94.0   15.0   57.0  377.0   0.862385      543.0
# 3216  0500000US51001    51.0   54.0   90.0   66.0   0.485714      261.0
# 3217  0500000US51021     8.0    0.0    5.0   15.0   1.000000       28.0
# 3218  0500000US51027    30.0   19.0   39.0    9.0   0.612245       97.0
# 3219  0500000US51037     5.0    6.0   10.0   18.0   0.454545       39.0
# 3220  0500000US51041  1947.0  144.0  276.0  175.0   0.931133     2542.0
#
#       ratio_tot             city state     fdid  ratio_score
# 0      0.252475       Prattville    AL  AL00401         75.0
# 1      0.266667          Oneonta    AL  AL00801         73.0
# 2      0.204724           Valley    AL  AL01208         80.0
# 3      0.212000          Verbena    AL  AL00407         79.0
# 4      0.127660        SHEFFIELD    AL  AL02001         87.0
# 5      0.172932       Enterprise    AL  AL01902         83.0
# 6      0.249147       Prattville    AL  AL00401         75.0
# 7      0.294118       Greensboro    AL  AL03601         71.0
# 8      0.297297          Moulton    AL  AL04201         70.0
# 9      0.291339           Athens    AL  AL04401         71.0
# 10     0.268657      Monroeville    AL  AL05101         73.0
# 11     0.061224            Gordo    AL  AL05402         94.0
# 12     0.221258        Sylacauga    AL  AL06101         78.0
# 13     0.156627           Bethel    AK  AK27100         84.0
# 14     0.100000           Hoonah    AK  AK17200         90.0
# 15     0.302198            Kenai    AK  AK26100         70.0
# 16     0.292035           Kodiak    AK  AK28100         71.0
# 17     0.000000      Pilot Point    AK  AK29306        100.0
# 18     0.243243             NOME    AK  AK37100         76.0
# 19     0.295455         Kotzebue    AK  AK36100         70.0
# 20     0.135135          Klawock    AK  AK19703         86.0
# 21     0.210000          Clinton    AR  AR71009         79.0
# 22     0.215364  Pleasant Plains    AR  AR32008         78.0
# 23     0.229299          Pioneer    CA  CA03006         77.0
# 24     0.033333          Willows    CA  CA11065         97.0
# 25     0.107492        Clearlake    CA  CA17005         89.0
# 26     0.264151         Mariposa    CA  CA22025         74.0
# 27     0.435789             NAPA    CA  CA28010         56.0
# 28     0.327950         Anderson    CA  CA45010         67.0
# 29     0.246162          Modesto    CA  CA50005         75.0
# ...         ...              ...   ...      ...          ...
# 3191   0.248175           Kinder    LA  LA02005         75.0
# 3192   0.230088           Bunkie    LA  LA05005         77.0
# 3193   0.231373           Amelia    LA  LA51001         77.0
# 3194   0.130952       Waterproof    LA  LA54015         87.0
# 3195   0.227273            HOUMA    LA  LA55001         77.0
# 3196   0.241573         Danville    KY  KY11048         76.0
# 3197   0.272727          AUGUSTA    KY  KY12052         73.0
# 3198   0.331646      LOREAUVILLE    LA  LA23020         67.0
# 3199   0.238554          Crofton    KY  KY24112         76.0
# 3200   0.184211           Marion    KY  KY28131         82.0
# 3201   0.114723        Owensboro    KY  KY30135         89.0
# 3202   0.256944        Frankfort    KY  KY00170         74.0
# 3203   0.421053           Fulton    KY  KY38174         58.0
# 3204   0.188235        Flatwoods    KY  KY45202         81.0
# 3205   0.233010       Cumberland    KY  KY48229         77.0
# 3206   0.285714        WILD ROSE    WI  WI69010         71.0
# 3207   0.166667          LARAMIE    WY  WY01309         83.0
# 3208   0.063830          Rawlins    WY  WY07423         94.0
# 3209   0.333333        MOORCROFT    WY  WY11513         67.0
# 3210   0.181159           LANDER    WY  WY13521         82.0
# 3211   0.128571         CHEYENNE    WY  WY21307         87.0
# 3212   0.216418     Wardensville    WV  WV16101         78.0
# 3213   0.283465       Ravenswood    WV  WV18102         72.0
# 3214   0.407080         Jane Lew    WV  WV21102         59.0
# 3215   0.173112          Barnard    VT  VT14030         83.0
# 3216   0.195402       New Church    VA  VA00101         80.0
# 3217   0.285714            BLAND    VA  VA02101         71.0
# 3218   0.309278           Grundy    VA  VA02701         69.0
# 3219   0.128205          RED OAK    VA  VA03701         87.0
# 3220   0.765932          CHESTER    VA  VA04100         23.0
#
# [3221 rows x 12 columns]

# %%
import folium
import branca

colorscale = branca.colormap.linear.YlOrRd_09.scale(0, 100)
colorscale.caption = 'Percent of homes without fire alarms'

county_alarm_ratio = 100 - counties['ratio_score']

m = folium.Map(
    location=[48, -102],
    tiles='cartodbpositron',
    zoom_start=3
)

with open('../data/01_raw/us_counties_20m_topo.json','r') as f:
    county_geo = json.load(f)

# folium.Choropleth(
#     geo_data = county_geo,
#     name = 'choropleth',
#     data = df_all_county_ids,
#     columns = ['county_geoid','ratio_score'],
#     key_on='feature.id',
#     fill_color='OrRd',
#     fill_opacity=0.7,
#     line_opacity=0.2,
#     topojson = 'objects.us_counties_20m',
#     legend_name = 'Percent of homes without fire alarms',
#     overlay=True
# ).add_to(m)

folium.Choropleth(
    geo_data = county_geo,
    name = 'choropleth',
    data = df_all_county_ids,
    columns = ['county_geoid','tot_fires'],
    key_on='feature.id',
    fill_color='OrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    topojson = 'objects.us_counties_20m',
    legend_name = 'Percent of homes without fire alarms',
    overlay=True
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
