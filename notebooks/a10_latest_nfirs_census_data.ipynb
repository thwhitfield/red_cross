# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.set_option('display.max_columns',500)
sns.set()

# %%
nfirs_path = '../data/01_raw/NFIRS_2009_2016_Combined_Census_Tract.csv'
col_dtypes = {'GEOID':str}
nfirs = pd.read_csv(nfirs_path,
                    dtype = col_dtypes,
                    nrows=100)

# %%
nfirs.head()
# Out:
#          ID state   fdid  inc_no    city            street   zip5  \
# 0  rcp2_id1    AK  11100     211  JUNEAU    1700 ANGUS WAY  99801
# 1  rcp2_id2    AK  11100     470  JUNEAU  3221 PIONEER AVE  99801
# 2  rcp2_id3    AK  11100     556  JUNEAU   10231 HERON WAY  99801
# 3  rcp2_id4    AK  11100    1315  JUNEAU  6590 GLACIER HWY  99801
# 4  rcp2_id5    AK  11100    2151  JUNEAU  6590 GLACIER HWY  99801
#
#             inc_date  oth_inj  oth_death  exp_no  inc_type  prop_loss  \
# 0   1/3/2009 0:00:00      0.0        0.0       0       111    20000.0
# 1   1/6/2009 0:00:00      0.0        0.0       0       114        0.0
# 2   1/6/2009 0:00:00      0.0        0.0       0       111    20000.0
# 3  1/13/2009 0:00:00      0.0        0.0       0       113      200.0
# 4  1/21/2009 0:00:00      0.0        0.0       0       111    35000.0
#
#    cont_loss  tot_loss detector det_type det_power det_operat  det_effect  \
# 0     5000.0   25000.0        1        1         1          2         1.0
# 1        0.0       0.0      NaN      NaN       NaN        NaN         NaN
# 2     5000.0   25000.0        N      NaN       NaN        NaN         NaN
# 3       20.0     220.0      NaN      NaN       NaN        NaN         NaN
# 4     5000.0   40000.0        N      NaN       NaN        NaN         NaN
#
#    det_fail aes_pres  aes_type  aes_oper  no_spr_op  aes_fail  COUNTYFP  \
# 0       NaN        N       NaN       NaN        NaN       NaN     110.0
# 1       NaN      NaN       NaN       NaN        NaN       NaN     110.0
# 2       NaN        N       NaN       NaN        NaN       NaN     110.0
# 3       NaN      NaN       NaN       NaN        NaN       NaN     110.0
# 4       NaN        N       NaN       NaN        NaN       NaN     110.0
#
#   FUNCSTAT         GEOID  MATCH                      MATCHED_ADDRESS  \
# 0        S  2110000500.0  Match    1700 ANGUS WAY, JUNEAU, AK, 99801
# 1        S  2110000600.0  Match  3221 PIONEER AVE, JUNEAU, AK, 99801
# 2        S  2110000100.0  Match   10231 HERON WAY, JUNEAU, AK, 99801
# 3        S  2110000400.0  Match  6590 Glacier Hwy, JUNEAU, AK, 99801
# 4        S  2110000400.0  Match  6590 Glacier Hwy, JUNEAU, AK, 99801
#
#   MATCH_TYPE  MTFCC  NAME        NAMELSAD  \
# 0      Exact  G5020   5.0  Census Tract 5
# 1      Exact  G5020   6.0  Census Tract 6
# 2      Exact  G5020   1.0  Census Tract 1
# 3      Exact  G5020   4.0  Census Tract 4
# 4      Exact  G5020   4.0  Census Tract 4
#
#                         ORIGINAL_ADDRESS STATE  TIGER_LINE_ID TIGER_LINE_SIDE  \
# 0      1700 ANGUS WAY, JUNEAU, AK, 99801    AK    190964136.0               R
# 1    3221 PIONEER AVE, JUNEAU, AK, 99801    AK    190966361.0               R
# 2     10231 HERON WAY, JUNEAU, AK, 99801    AK    190962538.0               R
# 3  6590 GLACIER HWY, JUNEAU,  AK,  99801    AK    190963741.0               R
# 4  6590 GLACIER HWY, JUNEAU,  AK,  99801    AK    190963741.0               R
#
#    TRACTCE          X          Y  state_fips
# 0    500.0 -134.42440  58.306507         2.0
# 1    600.0 -134.43314  58.292686         2.0
# 2    100.0 -134.60330  58.402610         2.0
# 3    400.0 -134.51932  58.358955         2.0
# 4    400.0 -134.51932  58.358955         2.0
